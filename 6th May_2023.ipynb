# %%
import pandas as pd

# %%
import numpy as np
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
import math as m

# %%
#reading the data set
data=pd.read_csv('taxis.csv')

# %%
data.head(10)
# Out:
#                 pickup              dropoff  passengers  distance  fare   tip  \
# 0  2019-03-23 20:21:09  2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1  2019-03-04 16:11:55  2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2  2019-03-27 17:53:01  2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3  2019-03-10 01:23:59  2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4  2019-03-30 13:27:42  2019-03-30 13:37:14           3      2.16   9.0  1.10
# 5  2019-03-11 10:37:23  2019-03-11 10:47:31           1      0.49   7.5  2.16
# 6  2019-03-26 21:07:31  2019-03-26 21:17:29           1      3.65  13.0  2.00
# 7  2019-03-22 12:47:13  2019-03-22 12:58:17           0      1.40   8.5  0.00
# 8  2019-03-23 11:48:50  2019-03-23 12:06:14           1      3.63  15.0  1.00
# 9  2019-03-08 16:18:37  2019-03-08 16:26:57           1      1.52   8.0  1.00
#
#    tolls  total   color      payment                pickup_zone  \
# ...

# %%
print(data)
# Out:
#                    pickup              dropoff  passengers  distance   fare  \
# 0     2019-03-23 20:21:09  2019-03-23 20:27:24           1      1.60   7.00
# 1     2019-03-04 16:11:55  2019-03-04 16:19:00           1      0.79   5.00
# 2     2019-03-27 17:53:01  2019-03-27 18:00:25           1      1.37   7.50
# 3     2019-03-10 01:23:59  2019-03-10 01:49:51           1      7.70  27.00
# 4     2019-03-30 13:27:42  2019-03-30 13:37:14           3      2.16   9.00
# 5     2019-03-11 10:37:23  2019-03-11 10:47:31           1      0.49   7.50
# 6     2019-03-26 21:07:31  2019-03-26 21:17:29           1      3.65  13.00
# 7     2019-03-22 12:47:13  2019-03-22 12:58:17           0      1.40   8.50
# 8     2019-03-23 11:48:50  2019-03-23 12:06:14           1      3.63  15.00
# 9     2019-03-08 16:18:37  2019-03-08 16:26:57           1      1.52   8.00
# 10    2019-03-16 10:02:25  2019-03-16 10:22:29           1      3.90  17.00
# ...

# %%
data.head(10)
# Out:
#                 pickup              dropoff  passengers  distance  fare   tip  \
# 0  2019-03-23 20:21:09  2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1  2019-03-04 16:11:55  2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2  2019-03-27 17:53:01  2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3  2019-03-10 01:23:59  2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4  2019-03-30 13:27:42  2019-03-30 13:37:14           3      2.16   9.0  1.10
# 5  2019-03-11 10:37:23  2019-03-11 10:47:31           1      0.49   7.5  2.16
# 6  2019-03-26 21:07:31  2019-03-26 21:17:29           1      3.65  13.0  2.00
# 7  2019-03-22 12:47:13  2019-03-22 12:58:17           0      1.40   8.5  0.00
# 8  2019-03-23 11:48:50  2019-03-23 12:06:14           1      3.63  15.0  1.00
# 9  2019-03-08 16:18:37  2019-03-08 16:26:57           1      1.52   8.0  1.00
#
#    tolls  total   color      payment                pickup_zone  \
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
len(data)
# Out:
# 6433

# %%
data.dtypes
# Out:
# pickup              object
# dropoff             object
# passengers           int64
# distance           float64
# fare               float64
# tip                float64
# tolls              float64
# total              float64
# color               object
# payment             object
# pickup_zone         object
# dropoff_zone        object
# pickup_borough      object
# dropoff_borough     object
# dtype: object

# %%
data['pickup'].value_counts()
# Out:
# 2019-03-16 10:37:52    2
# 2019-03-28 08:21:02    2
# 2019-03-17 12:10:05    2
# 2019-03-27 21:37:43    2
# 2019-03-28 10:05:08    2
# 2019-03-24 00:12:23    2
# 2019-03-26 08:02:40    2
# 2019-03-18 20:39:17    2
# 2019-03-22 23:15:20    2
# 2019-03-13 17:27:27    2
# 2019-03-28 18:47:12    2
# 2019-03-19 14:40:14    2
# 2019-03-01 23:48:39    2
# 2019-03-11 20:28:00    2
# 2019-03-15 08:39:34    2
# 2019-03-13 10:57:06    2
# 2019-03-06 14:40:57    2
# 2019-03-07 19:54:40    2
# 2019-03-21 08:59:27    2
# 2019-03-21 05:01:14    1
# 2019-03-12 07:31:29    1
# 2019-03-12 04:07:08    1
# 2019-03-14 16:57:50    1
# 2019-03-14 22:04:04    1
# 2019-03-27 08:38:24    1
# 2019-03-30 22:57:52    1
# 2019-03-28 07:19:45    1
# 2019-03-08 08:28:24    1
# 2019-03-01 12:47:30    1
# 2019-03-20 15:10:47    1
#                       ..
# 2019-03-30 14:56:08    1
# 2019-03-11 11:42:54    1
# 2019-03-24 00:56:39    1
# 2019-03-20 09:04:16    1
# 2019-03-16 09:55:00    1
# 2019-03-07 18:36:52    1
# ...

# %%
data['passengers'].value_counts()
# Out:
# 1    4678
# 2     876
# 5     277
# 3     243
# 6     153
# 4     110
# 0      96
# Name: passengers, dtype: int64

# %%
data['fare'].value_counts()
# Out:
# 7.50     350
# 6.00     345
# 6.50     323
# 5.00     313
# 5.50     312
# 7.00     296
# 8.00     258
# 8.50     254
# 9.50     229
# 4.50     217
# 9.00     201
# 10.00    199
# 10.50    179
# 11.50    160
# 11.00    159
# 4.00     154
# 12.00    150
# 52.00    131
# 12.50    124
# 13.00    110
# 13.50    104
# 15.00    101
# 3.50      97
# 14.00     94
# 14.50     86
# 16.00     85
# 15.50     76
# 17.00     72
# 16.50     68
# 17.50     54
#         ...
# 84.00      1
# 37.18      1
# 58.50      1
# 86.14      1
# 48.50      1
# 56.74      1
# 46.01      1
# 51.50      1
# 65.00      1
# 26.58      1
# 31.67      1
# 21.40      1
# 44.20      1
# 28.16      1
# 69.06      1
# 26.32      1
# 22.43      1
# 93.50      1
# 33.01      1
# 40.56      1
# 21.08      1
# 38.61      1
# 17.26      1
# 33.67      1
# 96.50      1
# 41.53      1
# 18.48      1
# 48.89      1
# 37.61      1
# 31.80      1
# Name: fare, Length: 220, dtype: int64

# %%
data['tip'].value_counts()
# Out:
# 0.00     2311
# 1.00      312
# 2.00      211
# 2.16       89
# 1.86       79
# 3.00       77
# 2.36       74
# 2.26       74
# 1.96       73
# 1.50       71
# 1.76       69
# 2.06       64
# 1.66       58
# 1.95       57
# 2.46       53
# 2.66       52
# 2.76       52
# 2.15       51
# 1.56       49
# 2.45       46
# 2.96       43
# 5.00       42
# 3.16       41
# 1.20       40
# 2.86       40
# 1.75       38
# 3.06       38
# 2.56       36
# 2.05       36
# 2.25       36
#          ...
# 7.89        1
# 0.95        1
# 8.01        1
# 10.20       1
# 7.06        1
# 2.18        1
# 6.54        1
# 9.01        1
# 0.69        1
# 9.80        1
# 8.45        1
# 12.50       1
# 9.25        1
# 7.25        1
# 3.71        1
# 8.46        1
# 9.82        1
# 1.49        1
# 0.09        1
# 3.47        1
# 3.90        1
# 11.39       1
# 11.50       1
# 20.65       1
# 7.21        1
# 4.51        1
# 8.49        1
# 11.60       1
# 4.74        1
# 8.39        1
# ...

# %%
data['tolls'].value_counts()
# Out:
# 0.00     6083
# 5.76      324
# 2.64        7
# 11.52       4
# 6.12        2
# 12.50       2
# 5.54        2
# 4.75        1
# 5.75        1
# 16.26       1
# 18.90       1
# 8.40        1
# 17.28       1
# 24.02       1
# 8.50        1
# 9.50        1
# Name: tolls, dtype: int64

# %%
data['total'].value_counts()
# Out:
# 9.30      146
# 11.30     129
# 11.80     122
# 10.30     121
# 9.80      121
# 8.80      118
# 12.30     101
# 8.30      100
# 10.80      98
# 12.80      95
# 13.80      92
# 7.80       91
# 12.96      89
# 13.30      85
# 7.30       84
# 11.16      79
# 14.80      76
# 14.16      74
# 11.76      73
# 14.30      73
# 13.56      73
# 10.56      69
# 15.80      68
# 12.36      64
# 16.80      60
# 15.30      59
# 6.80       59
# 9.96       56
# 14.76      53
# 15.96      52
#          ...
# 73.01       1
# 65.06       1
# 5.38        1
# 27.38       1
# 18.33       1
# 44.54       1
# 13.33       1
# 12.49       1
# 61.08       1
# 23.46       1
# 22.93       1
# 46.86       1
# 30.69       1
# 44.45       1
# 19.76       1
# 52.05       1
# 38.76       1
# 36.05       1
# 17.82       1
# 11.54       1
# 40.05       1
# 43.55       1
# 25.63       1
# 56.31       1
# 51.56       1
# 61.32       1
# 10.95       1
# 16.73       1
# 100.49      1
# 20.46       1
# ...

# %%
data['color'].value_counts()
# Out:
# yellow    5451
# green      982
# Name: color, dtype: int64

# %%
data['payment'].value_counts()
# Out:
# credit card    4577
# cash           1812
# Name: payment, dtype: int64

# %%
data.isnull()
# Out:
#       pickup  dropoff  passengers  distance   fare    tip  tolls  total  \
# 0      False    False       False     False  False  False  False  False
# 1      False    False       False     False  False  False  False  False
# 2      False    False       False     False  False  False  False  False
# 3      False    False       False     False  False  False  False  False
# 4      False    False       False     False  False  False  False  False
# 5      False    False       False     False  False  False  False  False
# 6      False    False       False     False  False  False  False  False
# 7      False    False       False     False  False  False  False  False
# 8      False    False       False     False  False  False  False  False
# 9      False    False       False     False  False  False  False  False
# 10     False    False       False     False  False  False  False  False
# 11     False    False       False     False  False  False  False  False
# ...

# %%
data.isnull().sum()
# Out:
# pickup              0
# dropoff             0
# passengers          0
# distance            0
# fare                0
# tip                 0
# tolls               0
# total               0
# color               0
# payment            44
# pickup_zone        26
# dropoff_zone       45
# pickup_borough     26
# dropoff_borough    45
# dtype: int64

# %%
data.isnull().sum()/len(data)*100
# Out:
# pickup             0.000000
# dropoff            0.000000
# passengers         0.000000
# distance           0.000000
# fare               0.000000
# tip                0.000000
# tolls              0.000000
# total              0.000000
# color              0.000000
# payment            0.683973
# pickup_zone        0.404166
# dropoff_zone       0.699518
# pickup_borough     0.404166
# dropoff_borough    0.699518
# dtype: float64

# %%
data['distance'].fillna(0)
data['fare'].fillna(0)
data['tip'].fillna(0)
data['tolls'].fillna(0)
data['total'].fillna(0)
data['passengers'].fillna(0)
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       3
# 5       1
# 6       1
# 7       0
# 8       1
# 9       1
# 10      1
# 11      1
# 12      1
# 13      1
# 14      0
# 15      3
# 16      1
# 17      1
# 18      1
# 19      6
# 20      1
# 21      1
# 22      1
# 23      5
# 24      5
# 25      1
# 26      1
# 27      1
# 28      1
# 29      1
#        ..
# 6403    4
# 6404    1
# 6405    2
# 6406    1
# 6407    1
# 6408    1
# 6409    1
# 6410    1
# 6411    1
# 6412    5
# 6413    1
# 6414    2
# 6415    1
# 6416    1
# 6417    2
# 6418    1
# 6419    1
# 6420    2
# 6421    6
# 6422    1
# 6423    1
# 6424    1
# 6425    1
# 6426    1
# 6427    1
# 6428    1
# 6429    1
# 6430    1
# 6431    1
# 6432    1
# Name: passengers, Length: 6433, dtype: int64

# %%
data.isnull().sum()/len(data)*100
# Out:
# pickup             0.000000
# dropoff            0.000000
# passengers         0.000000
# distance           0.000000
# fare               0.000000
# tip                0.000000
# tolls              0.000000
# total              0.000000
# color              0.000000
# payment            0.683973
# pickup_zone        0.404166
# dropoff_zone       0.699518
# pickup_borough     0.404166
# dropoff_borough    0.699518
# dtype: float64

# %%
data['payment'].fillna(method='ffill',inplace=True)
data['pickup_zone'].fillna(method='ffill',inplace=True)
data['dropoff_zone'].fillna(method='ffill',inplace=True)
data['pickup_borough'].fillna(method='ffill',inplace=True)
data['dropoff_borough'].fillna(method='ffill',inplace=True)

# %%
data['distance'].skew()
# Out:
# 3.0082057890318215

# %%
data['fare'].skew()
# Out:
# 3.217462794607763

# %%
data['tip'].skew()
# Out:
# 2.665151563396707

# %%
data['tolls'].skew()
# Out:
# 5.074935611676601

# %%
data['total'].skew()
# Out:
# 3.0933326288688754

# %%
data.isnull().sum()/len(data)*100
# Out:
# pickup             0.0
# dropoff            0.0
# passengers         0.0
# distance           0.0
# fare               0.0
# tip                0.0
# tolls              0.0
# total              0.0
# color              0.0
# payment            0.0
# pickup_zone        0.0
# dropoff_zone       0.0
# pickup_borough     0.0
# dropoff_borough    0.0
# dtype: float64

# %%
#use groupby function on Total fare
data.groupby('payment')['total'].sum()
# Out:
# payment
# cash           26842.71
# credit card    92282.26
# Name: total, dtype: float64

# %%
data.groupby('color')['total'].sum()
# Out:
# color
# green      16186.91
# yellow    102938.06
# Name: total, dtype: float64

# %%
data.groupby(['color','payment'])['total'].sum()
# Out:
# color   payment
# green   cash            4569.73
#         credit card    11617.18
# yellow  cash           22272.98
#         credit card    80665.08
# Name: total, dtype: float64

# %%
data.groupby('payment')['total'].mean()
# Out:
# payment
# cash           14.724471
# credit card    20.017844
# Name: total, dtype: float64

# %%
data.groupby('color')['total'].mean()
# Out:
# color
# green     16.483615
# yellow    18.884252
# Name: total, dtype: float64

# %%
data.groupby(['color','payment'])['total'].mean()
# Out:
# color   payment
# green   cash           11.367488
#         credit card    20.029621
# yellow  cash           15.674159
#         credit card    20.016149
# Name: total, dtype: float64

# %% [markdown]
# # Distribution Plots

# %%
sns.boxplot(x=data['distance'])

# %%
sns.boxplot(x=data['fare'])

# %%
sns.boxplot(x=data['tip'])

# %%
sns.boxplot(x=data['tolls'])

# %%
sns.boxplot(x=data['total'])

# %%
#1ST Quartile
Q1=data['total'].quantile(q=0.25)
Q1
# Out:
# 10.8

# %%
Q3=data['total'].quantile(q=0.75)
Q3
# Out:
# 20.3

# %%
Q2=data['total'].quantile(q=0.50)
Q2
# Out:
# 14.16

# %%
data.columns
# Out:
# Index(['pickup', 'dropoff', 'passengers', 'distance', 'fare', 'tip', 'tolls',
#        'total', 'color', 'payment', 'pickup_zone', 'dropoff_zone',
#        'pickup_borough', 'dropoff_borough'],
#       dtype='object')

# %%
Upper=Q3
Upper
# Out:
# 20.3

# %%
data[data['total']>Upper]
# Out:
#                    pickup              dropoff  passengers  distance   fare  \
# 3     2019-03-10 01:23:59  2019-03-10 01:49:51           1      7.70  27.00
# 22    2019-03-28 17:20:54  2019-03-28 17:55:57           1      9.82  31.50
# 35    2019-03-01 17:39:58  2019-03-01 18:04:46           1      3.06  17.00
# 37    2019-03-21 18:41:58  2019-03-21 19:15:25           1      3.13  20.50
# 40    2019-03-07 15:15:46  2019-03-07 15:50:14           1      7.51  27.00
# 41    2019-03-24 18:42:56  2019-03-24 19:09:00           0      4.50  20.00
# 42    2019-03-30 23:59:14  2019-03-30 23:59:17           1      0.00  80.00
# 43    2019-03-27 19:39:16  2019-03-27 20:00:26           1      9.50  28.00
# 44    2019-03-14 07:19:29  2019-03-14 07:45:51           1      9.37  29.50
# 46    2019-03-20 11:40:59  2019-03-20 12:06:41           2      4.70  20.00
# 49    2019-03-04 21:35:00  2019-03-04 21:53:42           1      4.87  17.50
# ...

# %%
#If total is greater than upper limit then change that total value to upper
#removing extreme values from the total field
data['total1']=np.where(data['total']>Q3,Q3,data['total'])
data['total1']=np.where(data['total1']<Q1,Q1,data['total1'])
#np.where(data['total']>Q3,Q3,data['total'])
#data['total']=data['total'].where(data['total']>Upper,data['total']=Upper)

# %%
sns.boxplot(y=data['total1'])

# %%
max(data['total1'])
# Out:
# 20.3

# %%
min(data['total1'])
# Out:
# 10.8

# %%
sns.boxenplot(y=data['total1'])

# %%
##to check the skewness of the data
sns.distplot(data['total1'])

# %%
print(data['total1'].skew())
# Out:
# 0.2512967251645837

# %%
data.head(5)
# Out:
#                 pickup              dropoff  passengers  distance  fare   tip  \
# 0  2019-03-23 20:21:09  2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1  2019-03-04 16:11:55  2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2  2019-03-27 17:53:01  2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3  2019-03-10 01:23:59  2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4  2019-03-30 13:27:42  2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
# 3    0.0  36.95  yellow  credit card              Hudson Sq
# 4    0.0  13.40  yellow  credit card           Midtown East
#
#             dropoff_zone pickup_borough dropoff_borough  total1
# 0    UN/Turtle Bay South      Manhattan       Manhattan   12.95
# ...

# %%
sns.set_style('darkgrid')
sns.distplot(data['total1'],color='green')
print(data['total1'].skew())
# Out:
# 0.2512967251645837

# %%
sns.pairplot(data)

# %%
data.head(2)
# Out:
#                 pickup              dropoff  passengers  distance  fare   tip  \
# 0  2019-03-23 20:21:09  2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1  2019-03-04 16:11:55  2019-03-04 16:19:00           1      0.79   5.0  0.00
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
#
#             dropoff_zone pickup_borough dropoff_borough  total1
# 0    UN/Turtle Bay South      Manhattan       Manhattan   12.95
# 1  Upper West Side South      Manhattan       Manhattan    9.30

# %%
sns.pairplot(data,hue='color')

# %%
sns.pairplot(data,hue='payment')
# Out:
# C:\Users\gauriam\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\gauriam\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
data.corr()
# Out:
#             passengers  distance      fare       tip     tolls     total  \
# passengers    1.000000  0.009411  0.007637  0.021099 -0.002903  0.015708
# distance      0.009411  1.000000  0.920108  0.452589  0.635267  0.904676
# fare          0.007637  0.920108  1.000000  0.488612  0.609307  0.974358
# tip           0.021099  0.452589  0.488612  1.000000  0.413619  0.646186
# tolls        -0.002903  0.635267  0.609307  0.413619  1.000000  0.683142
# total         0.015708  0.904676  0.974358  0.646186  0.683142  1.000000
# total1        0.030926  0.603377  0.667861  0.486413  0.286988  0.687882
#
#               total1
# passengers  0.030926
# distance    0.603377
# fare        0.667861
# tip         0.486413
# tolls       0.286988
# total       0.687882
# total1      1.000000

# %%
sns.heatmap(data.corr(),annot=True)

# %%
data.head(2)
# Out:
#                 pickup              dropoff  passengers  distance  fare   tip  \
# 0  2019-03-23 20:21:09  2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1  2019-03-04 16:11:55  2019-03-04 16:19:00           1      0.79   5.0  0.00
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
#
#             dropoff_zone pickup_borough dropoff_borough  total1
# 0    UN/Turtle Bay South      Manhattan       Manhattan   12.95
# 1  Upper West Side South      Manhattan       Manhattan    9.30

# %%
sns.barplot(x='payment',y='total1',data=data,estimator=np.sum)

# %%
sns.barplot(x='color',y='total1',data=data,estimator=np.sum)

# %%
len(data)
# Out:
# 6433

# %%
sns.swarmplot(x='total1',y='payment',data=data,hue='color')

# %%
data.head(2)
# Out:
#                 pickup              dropoff  passengers  distance  fare   tip  \
# 0  2019-03-23 20:21:09  2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1  2019-03-04 16:11:55  2019-03-04 16:19:00           1      0.79   5.0  0.00
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
#
#             dropoff_zone pickup_borough dropoff_borough  total1
# 0    UN/Turtle Bay South      Manhattan       Manhattan   12.95
# 1  Upper West Side South      Manhattan       Manhattan    9.30

# %%
data['pickup_zone'].value_counts()
# Out:
# Midtown Center                         230
# Upper East Side South                  211
# Penn Station/Madison Sq West           210
# Clinton East                           208
# Midtown East                           198
# Upper East Side North                  186
# Times Sq/Theatre District              184
# Union Sq                               180
# Lincoln Square East                    177
# Murray Hill                            162
# East Village                           152
# JFK Airport                            151
# LaGuardia Airport                      146
# Upper West Side South                  144
# Midtown North                          141
# Midtown South                          141
# East Chelsea                           131
# Lenox Hill West                        120
# West Village                           110
# Gramercy                               109
# Garment District                       108
# Sutton Place/Turtle Bay North          106
# ...

# %%
#encoding functions
data['payment']=np.where(data['payment']=='cash',1,0)

# %%
data
# Out:
#                    pickup              dropoff  passengers  distance   fare  \
# 0     2019-03-23 20:21:09  2019-03-23 20:27:24           1      1.60   7.00
# 1     2019-03-04 16:11:55  2019-03-04 16:19:00           1      0.79   5.00
# 2     2019-03-27 17:53:01  2019-03-27 18:00:25           1      1.37   7.50
# 3     2019-03-10 01:23:59  2019-03-10 01:49:51           1      7.70  27.00
# 4     2019-03-30 13:27:42  2019-03-30 13:37:14           3      2.16   9.00
# 5     2019-03-11 10:37:23  2019-03-11 10:47:31           1      0.49   7.50
# 6     2019-03-26 21:07:31  2019-03-26 21:17:29           1      3.65  13.00
# 7     2019-03-22 12:47:13  2019-03-22 12:58:17           0      1.40   8.50
# 8     2019-03-23 11:48:50  2019-03-23 12:06:14           1      3.63  15.00
# 9     2019-03-08 16:18:37  2019-03-08 16:26:57           1      1.52   8.00
# 10    2019-03-16 10:02:25  2019-03-16 10:22:29           1      3.90  17.00
# ...

# %%
#pivot table
data.pivot_table(values='total1',columns=['payment','color'],index='distance',aggfunc='sum')
# Out:
# payment       0             1
# color     green  yellow green yellow
# distance
# 0.00      93.61  263.47  86.8   71.8
# 0.01        NaN     NaN   NaN    4.3
# 0.02       3.30     NaN   NaN    9.6
# 0.03        NaN     NaN   NaN    3.8
# 0.04        NaN     NaN   NaN    3.8
# 0.07        NaN    4.30   3.8    3.8
# 0.08        NaN     NaN   3.3    NaN
# 0.09        NaN     NaN   3.8    7.3
# 0.10       7.60   34.25   NaN    8.6
# 0.11        NaN   20.30   NaN    NaN
# 0.12        NaN    8.30   4.8    NaN
# 0.13        NaN     NaN   NaN    5.8
# 0.15       8.40     NaN   9.1    NaN
# 0.16      12.96     NaN   4.3    9.3
# 0.17        NaN     NaN   NaN    7.3
# 0.18        NaN     NaN   4.3    NaN
# 0.19        NaN     NaN   7.6    NaN
# 0.20        NaN   74.22   NaN   36.8
# 0.21        NaN     NaN   NaN    6.8
# 0.22        NaN     NaN   NaN    7.3
# 0.25        NaN     NaN   NaN   14.6
# 0.26        NaN   10.14   NaN    4.8
# 0.27       4.30   18.20   NaN    NaN
# ...

# %%
data.groupby(['payment','color']).size().plot(kind='barh')

# %%
plt.figure(figsize=(10,3))
sns.lineplot(x='payment',y='total1',data=data,estimator='sum',hue='color')
